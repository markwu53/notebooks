# %%
print("Hello Python")
# Out:
# Hello Python

# %% [markdown]
# Introduction to Python Data Analytics Packages
# ==============================================

# %% [markdown]
# ### Python data analytics packages include:
#
# * Numpy
# * [Scipy](http://docs.scipy.org/doc/scipy/reference/)
# * Sympy
# * Pandas
# * [Matplotlib](http://matplotlib.org/contents.html)

# %% [markdown]
# ### Scipy -- Special Functions
#
# Bessel functions are a family of solutions to Bessel’s differential equation:
#
# $$
# x^2\frac{d^2y}{dx^2} + x\frac{dy}{dx} + (x^2 - \alpha^2)y = 0
# $$

# %% [markdown]
# We need to import Numpy and Scipy:

# %%
import numpy as np
from scipy import special

# %% [markdown]
# Then we define a function:

# %%
def drumhead_height(n, k, distance, angle, t):
   kth_zero = special.jn_zeros(n, k)[-1]
   return np.cos(t) * np.cos(n*angle) * special.jn(n, distance*kth_zero)

# %% [markdown]
# Then for a grid of points $(x,y)$, we calculate $z=f(x,y)$, where $f$ is the Bessel function of order $0$:

# %%
theta = np.r_[0:2*np.pi:50j]
radius = np.r_[0:1:50j]
x = np.array([r * np.cos(theta) for r in radius])
y = np.array([r * np.sin(theta) for r in radius])
z = np.array([drumhead_height(1, 1, r, theta, 0.5) for r in radius])

# %% [markdown]
# To plot the graph, we need to import Matplotlib:

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# %% [markdown]
# Don't forget to add the magic line:

# %%
# %matplotlib inline

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(x, y, z, rstride=1, cstride=1, cmap=cm.jet)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()

# %% [markdown]
# ## That's it.
